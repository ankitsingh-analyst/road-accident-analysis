# %%
import pandas as pd

# %%
df = pd.read_csv('Road_Accident_Data.csv')

df.head()
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    01-01-2021    Thursday  Give way or uncontrolled
# 1      BS0000002    05-01-2021      Monday  Give way or uncontrolled
# 2      BS0000003    04-01-2021      Sunday  Give way or uncontrolled
# 3      BS0000004    05-01-2021      Monday       Auto traffic signal
# 4      BS0000005    06-01-2021     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                 NaN  ...
# ...

# %%
df.isnull().sum()
# Out:
# Accident_Index                     0
# Accident Date                      0
# Day_of_Week                        0
# Junction_Control                   0
# Junction_Detail                    0
# Accident_Severity                  0
# Latitude                           0
# Light_Conditions                   0
# Local_Authority_(District)         0
# Carriageway_Hazards           302549
# Longitude                          0
# Number_of_Casualties               0
# Number_of_Vehicles                 0
# Police_Force                       0
# Road_Surface_Conditions            0
# Road_Type                          0
# Speed_limit                        0
# Time                              17
# Urban_or_Rural_Area                0
# Weather_Conditions                 0
# Vehicle_Type                       0
# dtype: int64

# %%
df.dtypes
# Out:
# Accident_Index                    str
# Accident Date                     str
# Day_of_Week                       str
# Junction_Control                  str
# Junction_Detail                   str
# Accident_Severity                 str
# Latitude                      float64
# Light_Conditions                  str
# Local_Authority_(District)        str
# Carriageway_Hazards               str
# Longitude                     float64
# Number_of_Casualties            int64
# Number_of_Vehicles              int64
# Police_Force                      str
# Road_Surface_Conditions           str
# Road_Type                         str
# Speed_limit                     int64
# Time                              str
# Urban_or_Rural_Area               str
# Weather_Conditions                str
# Vehicle_Type                      str
# dtype: object

# %%
y = []

for i in range(len(df)):
    x = tuple(df.iloc[i])
    y.append(x)

print(y[:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 y = []
#       3 for i in range(len(df)):
# ----> 4     x = tuple(df.iloc[i])
#       5     y.append(x)
#       7 print(y[:5])
#
# TypeError: 'tuple' object is not callable

# %%
file = open('Road_Accident_Data.txt', 'w')
for tuple in y:
    file.write(str(tuple) + ',' + '\n')

file.close()

# %%
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqldb://root:#12345678@localhost:3306/Road_Accident")
conn = engine.connect()
data = pd.read_csv("Road_Accident_Data.csv")
data.to_sql('Accident_Data',engine, index=False, if_exist='replace')
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import warnings
#       2 warnings.filterwarnings('ignore')
# ----> 3 from sqlalchemy import create_engine
#       4 engine = create_engine("mysql+mysqldb://root:#12345678@localhost:3306/Road_Accident")
#       5 conn = engine.connect()
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib

# Encode password (VERY IMPORTANT if special characters exist)
password = urllib.parse.quote_plus("#12345678")

# Use pymysql instead of mysqldb (more reliable)
engine = create_engine(f"mysql+pymysql://root:#12345678@localhost:3306/Road_Accident")

# Read CSV
data = pd.read_csv("Road_Accident_Data.csv")

# Upload to MySQL
data.to_sql('Accident_Data', con=engine, index=False, if_exists='replace')

print("Data imported successfully!")
# Out:
# Data imported successfully!

# %%
pip install sqlalchemy pandas pymysql
# Out:
# ...
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/f2/af/c3c7e1f3a2b383155a16454df62ae8c62a30dd238e42e68c24cebebbfae6/sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/7c/4c/ad33b92b9864cbde84f259d5df035a6447f91891f5be77788e2a3892bce3/pymysql-1.1.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/9b/40/cc802e067d02af8b60b6771cea7d57e21ef5e6659912814babb42b864713/greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for typing-extensions>=4.6.0 from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
# ...
